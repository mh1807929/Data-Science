# %%
from datascience import *
# %matplotlib inline
import matplotlib.pyplot as plots
plots.style.use('fivethirtyeight')
import numpy as np
import warnings
warnings.simplefilter(action='ignore', category=np.VisibleDeprecationWarning)

# %% [markdown]
# ## Discussion Question: Super Soda

# %%
observed_ts = 91
def one_sim():
    return int(200 * sample_proportions(200, [0.5, 0.5])[0])
one_sim()
# Out:
# 103

# %%
array = make_array()
for i in np.arange(10000):
    v = one_sim()
    array = np.append(v, array)
array
# Out:
# array([ 101.,  105.,   97., ...,   97.,  114.,  108.])

# %%
trials = Table().with_column('soda count', array)
trials.hist(right_end=91)
plots.ylim(-0.001, 0.055)
plots.scatter(91, 0, color='red', s=40, zorder=3)
plots.title('Prediction Under the Null');

# %%
p_value = sum(array<=91)/len(array)

p_value
# Out:
# 0.1153

# %% [markdown]
# Conclusion:
